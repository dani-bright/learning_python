# %%
import warnings
import seaborn as sns
import pandas as pd
warnings.filterwarnings('ignore')

hp = pd.read_csv('house_pricing.csv')

hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

hp = pd.read_csv('house_pricing.csv')

hp.plot.scatter(x='LotArea',y='SalePrice')

filterLotPrice = hp[hp.LotArea<20000][hp.SalePrice<500000]


sns.relplot(kind='scatter', x='LotArea',y='SalePrice', data=filterLotPrice)

# %%
sns.relplot(x="date", y="item_price", data = sp)

f, ax = plt.subplots(figsize=(20,6))
sns.relplot(x="date", y="item_price", data = sp.sample(50), kind="line", ax = ax)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd    

date =  pd.to_datetime(sp['date'])
sns.relplot(x=date, y="item_price", data = sp.sample(50), kind="line")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-1e09470622c8> in <module>
#       4
#       5 date =  pd.to_datetime(sp['date'])
# ----> 6 sns.relplot(x=date, y="item_price", data = sp.sample(50), kind="line")
#
# c:\users\bebli\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1693
#    1694     # Draw the plot
# -> 1695     g.map_dataframe(func, x, y,
#    1696                     hue=hue, size=size, style=style,
#    1697                     **plot_kws)
#
# c:\users\bebli\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
# ...

# %%
# exercice 3
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

dt = pd.read_csv('ibm.csv')
dt.describe()
sns.catplot(x='Attrition', y='JobSatisfaction', kind="bar", data=dt)

# %%
dt = pd.read_csv('ibm.csv')
dt.describe()
sns.boxplot(x='Attrition', y='JobSatisfaction', data=dt)

# %%
sns.catplot(x="TotalWorkingYears", y="Attrition", data =dt, kind= "box", height=10)

# %%
dt.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
dt['Attrition'] = dt['Attrition'].replace('Yes', 1)
dt['Attrition'] = dt['Attrition'].replace('No', 0)
sns.catplot(x='Attrition', y='EducationField', kind="bar", data=dt)

# %%
sns.distplot(dt['MonthlyIncome'], kde = False, hist_kws = {'color': 'red', 'alpha': 0.2})

# %%
filtered_data = dt.loc[(dt['MonthlyIncome'] > 0) &(dt['MonthlyIncome'] < 5000)]
sns.distplot(filtered_data['MonthlyIncome'], kde = False, hist_kws = {'color': 'red', 'alpha': 0.2})

# %%
sns.lmplot(x="DistanceFromHome", y="Attrition", data=dt)

# %%
sns.lmplot(x="YearsWithCurrManager", y="Attrition", data=dt)

# %%
import warnings
import seaborn as sns
import pandas as pd
warnings.filterwarnings('ignore')

hp = pd.read_csv('house_pricing.csv',usecols=['SalePrice','SaleCondition','SaleType','YrSold','MoSold',
           'MiscVal','MiscFeature','Fence','PoolQC','PoolArea',
          'ScreenPorch','3SsnPorch','EnclosedPorch','OpenPorchSF','WoodDeckSF'])

hp.corr()
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
corrMatrix= hp.corr()

sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
import warnings
import seaborn as sns
import pandas as pd

re = pd.read_csv('resto.csv')

re.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
re.size
# Out:
# 27732

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 162.6+ KB

# %%
#re.item_name.mode()
re['item_name'].value_counts()[:1].index.tolist()
# Out:
# ['Chicken Bowl']

# %%
re['order_id'].count()
# Out:
# 4622

# %%
prices =  re['item_price'].str.replace('$', '').astype(float)
prices.sum()
# Out:
# 34500.16
